# %%
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
#from keras.layers import BatchNormalization
from keras.models import Model
from keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import os
import PIL
import PIL.Image
import pathlib
from sklearn.model_selection import train_test_split
data_dir = pathlib.Path("/Users/Davran/0_Deep_Learning_Project/Insulator Inspection/Insulator")
data_dir_train = pathlib.Path("/Users/Davran/0_Deep_Learning_Project/Insulator Inspection/Insulator/All/*/*")
#data_dir_test = pathlib.Path("C:/Users/Davran/0_Deep_Learning_Project/Implant Inspection/test/*/*")

# %%
filenames = tf.io.gfile.glob(str(data_dir_train))
#filenames.extend(tf.io.gfile.glob(str(data_dir_test)))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %%
COUNT_CLEAN = len([filename for filename in filenames if "Clean" in filename])
print("Clean images count in training set: " + str(COUNT_CLEAN))

COUNT_POLLUTED = len([filename for filename in filenames if "Polluted" in filename])
print("Polluted images count in training set: " + str(COUNT_POLLUTED))
# Out:
# Clean images count in training set: 71
# Polluted images count in training set: 205

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'\\Users\\Davran\\0_Deep_Learning_Project\\Insulator Inspection\\Insulator\\All\\Polluted\\20200617_125006.jpg'
# b'\\Users\\Davran\\0_Deep_Learning_Project\\Insulator Inspection\\Insulator\\All\\Polluted\\20200617_130006.jpg'
# b'\\Users\\Davran\\0_Deep_Learning_Project\\Insulator Inspection\\Insulator\\All\\Polluted\\20200617_124023.jpg'
# b'\\Users\\Davran\\0_Deep_Learning_Project\\Insulator Inspection\\Insulator\\All\\Polluted\\20200617_124610.jpg'
# b'\\Users\\Davran\\0_Deep_Learning_Project\\Insulator Inspection\\Insulator\\All\\Clean\\20200617_123552.jpg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Train images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validation images count: " + str(VAL_IMG_COUNT))
# Out:
# Train images count: 220
# Validation images count: 56

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(data_dir) + "/All/*")])
CLASS_NAMES
# Out:
# array(['Clean', 'Polluted'], dtype='<U8')

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    if parts[-2] == 'Clean':
        return 0
    else:
        return 1

# %%
def decode_img(img):
    # convert the compressed string
    img_X = tf.image.decode_jpeg(img, channels=3)
    # Use `convert_image_dtype` to convert to floats in the [0,1] range.
    img_X = tf.keras.layers.Rescaling(scale=1./127.5, offset=-1)(img_X)
    #img_X = tf.image.convert_image_dtype(img_X, tf.float32)
    # resize the image to the desired size.
    return tf.image.resize(img_X, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
IMAGE_SIZE = (224, 224)
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
X_train = []
y_train = []

for image, label in train_ds:
    X_train.append(image)
    y_train.append(label)    
X_train = np.array(X_train, dtype = 'float32')
y_train = np.array(y_train, dtype = 'float32')

shuffled_idx = np.random.permutation(TRAIN_IMG_COUNT)
X_train[:] = X_train[shuffled_idx]
y_train[:] = y_train[shuffled_idx]
print(X_train.shape)
print(y_train.shape)
# Out:
# (220, 224, 224, 3)
# (220,)

# %%
X_val = []
y_val = []

for image, label in val_ds:
    X_val.append(image)
    y_val.append(label)    
X_val = np.array(X_val, dtype = 'float32')
y_val = np.array(y_val, dtype = 'float32')

shuffled_idx = np.random.permutation(VAL_IMG_COUNT)
X_val[:] = X_val[shuffled_idx]
y_val[:] = y_val[shuffled_idx]
print(X_val.shape)
print(y_val.shape)
# Out:
# (56, 224, 224, 3)
# (56,)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (10, 10))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap = plt.cm.binary)
    plt.xlabel(y_train[i])
    
# The figure below shows the downsampled images of insulators with the labels below.
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#X_train = np.expand_dims(X_train, axis=0)

# %%
#X_train.shape

# %%
IMG_SHAPE = IMAGE_SIZE + (3, )
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
#image_batch, label_batch = next(iter(X_train))
feature_batch = base_model(X_train)
print(feature_batch.shape)
# Out:
# (220, 7, 7, 1280)

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (220, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (220, 1)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
#x = data_augmentation(inputs)
#x = preprocess_input(inputs)
x = base_model(inputs, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 1)                 1281
#
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
type(X_val)
# Out:
# numpy.ndarray

# %%
tf.config.run_functions_eagerly(True)

# %%
initial_epochs = 150

loss0, accuracy0 = model.evaluate(X_val, y_val)
# Out:
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2761 - accuracy: 0.2188
# C:\Users\Davran\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4526: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 2/2 [==============================] - 0s 62ms/step - loss: 1.1508 - accuracy: 0.3214

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=initial_epochs,
                    validation_data = (X_val, y_val)
                    )
# Out:
# Epoch 1/150
# 7/7 [==============================] - 4s 147ms/step - loss: 1.2466 - accuracy: 0.2364 - val_loss: 1.0117 - val_accuracy: 0.3214
# Epoch 2/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.9708 - accuracy: 0.2818 - val_loss: 0.9099 - val_accuracy: 0.3393
# Epoch 3/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.9418 - accuracy: 0.2727 - val_loss: 0.8397 - val_accuracy: 0.3214
# Epoch 4/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.7993 - accuracy: 0.3227 - val_loss: 0.7978 - val_accuracy: 0.2321
# Epoch 5/150
# 7/7 [==============================] - 1s 177ms/step - loss: 0.7664 - accuracy: 0.3955 - val_loss: 0.7750 - val_accuracy: 0.2857
# Epoch 6/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.7137 - accuracy: 0.4591 - val_loss: 0.7602 - val_accuracy: 0.3393
# Epoch 7/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.7226 - accuracy: 0.4364 - val_loss: 0.7484 - val_accuracy: 0.3750
# Epoch 8/150
# 7/7 [==============================] - 1s 121ms/step - loss: 0.6709 - accuracy: 0.5455 - val_loss: 0.7352 - val_accuracy: 0.4821
# Epoch 9/150
# 7/7 [==============================] - 1s 120ms/step - loss: 0.6865 - accuracy: 0.5182 - val_loss: 0.7223 - val_accuracy: 0.5357
# Epoch 10/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.6734 - accuracy: 0.5273 - val_loss: 0.7072 - val_accuracy: 0.5536
# Epoch 11/150
# 7/7 [==============================] - 1s 120ms/step - loss: 0.6558 - accuracy: 0.5818 - val_loss: 0.6912 - val_accuracy: 0.5714
# Epoch 12/150
# 7/7 [==============================] - 1s 119ms/step - loss: 0.6196 - accuracy: 0.6136 - val_loss: 0.6746 - val_accuracy: 0.6071
# Epoch 13/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.6083 - accuracy: 0.5818 - val_loss: 0.6596 - val_accuracy: 0.6250
# Epoch 14/150
# 7/7 [==============================] - 1s 119ms/step - loss: 0.5623 - accuracy: 0.6545 - val_loss: 0.6462 - val_accuracy: 0.6250
# Epoch 15/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.5894 - accuracy: 0.6500 - val_loss: 0.6316 - val_accuracy: 0.6250
# Epoch 16/150
# 7/7 [==============================] - 1s 121ms/step - loss: 0.5486 - accuracy: 0.6682 - val_loss: 0.6199 - val_accuracy: 0.6429
# Epoch 17/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.5763 - accuracy: 0.6636 - val_loss: 0.6079 - val_accuracy: 0.6429
# Epoch 18/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.5405 - accuracy: 0.6909 - val_loss: 0.5970 - val_accuracy: 0.6607
# Epoch 19/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.5583 - accuracy: 0.6545 - val_loss: 0.5876 - val_accuracy: 0.6607
# Epoch 20/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.5316 - accuracy: 0.7091 - val_loss: 0.5806 - val_accuracy: 0.6786
# Epoch 21/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.5173 - accuracy: 0.7000 - val_loss: 0.5709 - val_accuracy: 0.6964
# Epoch 22/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.5104 - accuracy: 0.7000 - val_loss: 0.5632 - val_accuracy: 0.7143
# Epoch 23/150
# 7/7 [==============================] - 1s 134ms/step - loss: 0.4742 - accuracy: 0.7636 - val_loss: 0.5569 - val_accuracy: 0.7143
# Epoch 24/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.4708 - accuracy: 0.7727 - val_loss: 0.5499 - val_accuracy: 0.7143
# Epoch 25/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.5044 - accuracy: 0.7500 - val_loss: 0.5429 - val_accuracy: 0.7321
# Epoch 26/150
# 7/7 [==============================] - 1s 121ms/step - loss: 0.4933 - accuracy: 0.7636 - val_loss: 0.5363 - val_accuracy: 0.7500
# Epoch 27/150
# 7/7 [==============================] - 1s 121ms/step - loss: 0.4771 - accuracy: 0.7318 - val_loss: 0.5308 - val_accuracy: 0.7500
# Epoch 28/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.4766 - accuracy: 0.7500 - val_loss: 0.5229 - val_accuracy: 0.7679
# Epoch 29/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.4646 - accuracy: 0.7591 - val_loss: 0.5142 - val_accuracy: 0.7857
# Epoch 30/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.4413 - accuracy: 0.7864 - val_loss: 0.5074 - val_accuracy: 0.7857
# Epoch 31/150
# 7/7 [==============================] - 1s 129ms/step - loss: 0.4395 - accuracy: 0.7818 - val_loss: 0.5011 - val_accuracy: 0.8036
# Epoch 32/150
# 7/7 [==============================] - 1s 129ms/step - loss: 0.4528 - accuracy: 0.7682 - val_loss: 0.4947 - val_accuracy: 0.8036
# Epoch 33/150
# 7/7 [==============================] - 1s 130ms/step - loss: 0.4255 - accuracy: 0.7909 - val_loss: 0.4905 - val_accuracy: 0.8036
# Epoch 34/150
# 7/7 [==============================] - 1s 128ms/step - loss: 0.4312 - accuracy: 0.7727 - val_loss: 0.4864 - val_accuracy: 0.8036
# Epoch 35/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.4101 - accuracy: 0.7773 - val_loss: 0.4824 - val_accuracy: 0.8036
# Epoch 36/150
# 7/7 [==============================] - 1s 120ms/step - loss: 0.3779 - accuracy: 0.8455 - val_loss: 0.4786 - val_accuracy: 0.8036
# Epoch 37/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.4011 - accuracy: 0.8091 - val_loss: 0.4730 - val_accuracy: 0.8036
# Epoch 38/150
# 7/7 [==============================] - 1s 135ms/step - loss: 0.4137 - accuracy: 0.8000 - val_loss: 0.4696 - val_accuracy: 0.8036
# Epoch 39/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.4251 - accuracy: 0.8136 - val_loss: 0.4670 - val_accuracy: 0.8036
# Epoch 40/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.3900 - accuracy: 0.7909 - val_loss: 0.4644 - val_accuracy: 0.8036
# Epoch 41/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.3729 - accuracy: 0.8227 - val_loss: 0.4580 - val_accuracy: 0.8036
# Epoch 42/150
# 7/7 [==============================] - 1s 146ms/step - loss: 0.4014 - accuracy: 0.8045 - val_loss: 0.4543 - val_accuracy: 0.8036
# Epoch 43/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.4111 - accuracy: 0.8091 - val_loss: 0.4514 - val_accuracy: 0.8036
# Epoch 44/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.3880 - accuracy: 0.8091 - val_loss: 0.4480 - val_accuracy: 0.8036
# Epoch 45/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.3603 - accuracy: 0.8455 - val_loss: 0.4463 - val_accuracy: 0.8036
# Epoch 46/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.3634 - accuracy: 0.8591 - val_loss: 0.4395 - val_accuracy: 0.8393
# Epoch 47/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3645 - accuracy: 0.8500 - val_loss: 0.4338 - val_accuracy: 0.8393
# Epoch 48/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3603 - accuracy: 0.8409 - val_loss: 0.4286 - val_accuracy: 0.8571
# Epoch 49/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3748 - accuracy: 0.8273 - val_loss: 0.4258 - val_accuracy: 0.8393
# Epoch 50/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3630 - accuracy: 0.8455 - val_loss: 0.4233 - val_accuracy: 0.8393
# Epoch 51/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3749 - accuracy: 0.8091 - val_loss: 0.4229 - val_accuracy: 0.8393
# Epoch 52/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3557 - accuracy: 0.8545 - val_loss: 0.4196 - val_accuracy: 0.8571
# Epoch 53/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3280 - accuracy: 0.8500 - val_loss: 0.4163 - val_accuracy: 0.8571
# Epoch 54/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3525 - accuracy: 0.8636 - val_loss: 0.4131 - val_accuracy: 0.8571
# Epoch 55/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3350 - accuracy: 0.8545 - val_loss: 0.4103 - val_accuracy: 0.8571
# Epoch 56/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3431 - accuracy: 0.8591 - val_loss: 0.4052 - val_accuracy: 0.8393
# Epoch 57/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3198 - accuracy: 0.8909 - val_loss: 0.4018 - val_accuracy: 0.8393
# Epoch 58/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.3337 - accuracy: 0.8409 - val_loss: 0.3999 - val_accuracy: 0.8393
# Epoch 59/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3609 - accuracy: 0.8227 - val_loss: 0.3998 - val_accuracy: 0.8393
# Epoch 60/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2977 - accuracy: 0.8909 - val_loss: 0.3957 - val_accuracy: 0.8571
# Epoch 61/150
# 7/7 [==============================] - 1s 121ms/step - loss: 0.3232 - accuracy: 0.8591 - val_loss: 0.3929 - val_accuracy: 0.8571
# Epoch 62/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3343 - accuracy: 0.8591 - val_loss: 0.3919 - val_accuracy: 0.8571
# Epoch 63/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3291 - accuracy: 0.8545 - val_loss: 0.3900 - val_accuracy: 0.8571
# Epoch 64/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3137 - accuracy: 0.8773 - val_loss: 0.3862 - val_accuracy: 0.8571
# Epoch 65/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3264 - accuracy: 0.8727 - val_loss: 0.3826 - val_accuracy: 0.8571
# Epoch 66/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3039 - accuracy: 0.9000 - val_loss: 0.3802 - val_accuracy: 0.8750
# Epoch 67/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2823 - accuracy: 0.9000 - val_loss: 0.3783 - val_accuracy: 0.8750
# Epoch 68/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3235 - accuracy: 0.8682 - val_loss: 0.3746 - val_accuracy: 0.8750
# Epoch 69/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2945 - accuracy: 0.8909 - val_loss: 0.3727 - val_accuracy: 0.8750
# Epoch 70/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3124 - accuracy: 0.8909 - val_loss: 0.3710 - val_accuracy: 0.8750
# Epoch 71/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3205 - accuracy: 0.8773 - val_loss: 0.3675 - val_accuracy: 0.8750
# Epoch 72/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3003 - accuracy: 0.8818 - val_loss: 0.3654 - val_accuracy: 0.8750
# Epoch 73/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3006 - accuracy: 0.8864 - val_loss: 0.3626 - val_accuracy: 0.8929
# Epoch 74/150
# 7/7 [==============================] - 1s 121ms/step - loss: 0.2923 - accuracy: 0.8909 - val_loss: 0.3594 - val_accuracy: 0.8929
# Epoch 75/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3105 - accuracy: 0.8591 - val_loss: 0.3579 - val_accuracy: 0.8929
# Epoch 76/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3091 - accuracy: 0.8636 - val_loss: 0.3556 - val_accuracy: 0.8929
# Epoch 77/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3080 - accuracy: 0.8636 - val_loss: 0.3534 - val_accuracy: 0.8929
# Epoch 78/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2984 - accuracy: 0.8773 - val_loss: 0.3515 - val_accuracy: 0.8929
# Epoch 79/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.3046 - accuracy: 0.8636 - val_loss: 0.3498 - val_accuracy: 0.8929
# Epoch 80/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2703 - accuracy: 0.9091 - val_loss: 0.3487 - val_accuracy: 0.8929
# Epoch 81/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2988 - accuracy: 0.8727 - val_loss: 0.3478 - val_accuracy: 0.8929
# Epoch 82/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2722 - accuracy: 0.8955 - val_loss: 0.3470 - val_accuracy: 0.9107
# Epoch 83/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2766 - accuracy: 0.8818 - val_loss: 0.3456 - val_accuracy: 0.9107
# Epoch 84/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2713 - accuracy: 0.9045 - val_loss: 0.3439 - val_accuracy: 0.9107
# Epoch 85/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2606 - accuracy: 0.8909 - val_loss: 0.3437 - val_accuracy: 0.9107
# Epoch 86/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.2755 - accuracy: 0.9000 - val_loss: 0.3412 - val_accuracy: 0.9107
# Epoch 87/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2517 - accuracy: 0.9136 - val_loss: 0.3379 - val_accuracy: 0.9107
# Epoch 88/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2638 - accuracy: 0.9000 - val_loss: 0.3341 - val_accuracy: 0.9107
# Epoch 89/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2590 - accuracy: 0.9000 - val_loss: 0.3314 - val_accuracy: 0.9107
# Epoch 90/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2565 - accuracy: 0.9091 - val_loss: 0.3307 - val_accuracy: 0.9107
# Epoch 91/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2707 - accuracy: 0.8955 - val_loss: 0.3270 - val_accuracy: 0.9107
# Epoch 92/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2590 - accuracy: 0.9091 - val_loss: 0.3256 - val_accuracy: 0.9107
# Epoch 93/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2590 - accuracy: 0.9045 - val_loss: 0.3244 - val_accuracy: 0.9107
# Epoch 94/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2519 - accuracy: 0.9000 - val_loss: 0.3232 - val_accuracy: 0.9107
# Epoch 95/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2567 - accuracy: 0.9136 - val_loss: 0.3229 - val_accuracy: 0.9107
# Epoch 96/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2540 - accuracy: 0.9045 - val_loss: 0.3221 - val_accuracy: 0.9107
# Epoch 97/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.2496 - accuracy: 0.9091 - val_loss: 0.3211 - val_accuracy: 0.9107
# Epoch 98/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.2636 - accuracy: 0.8818 - val_loss: 0.3191 - val_accuracy: 0.9107
# Epoch 99/150
# 7/7 [==============================] - 1s 129ms/step - loss: 0.2591 - accuracy: 0.9000 - val_loss: 0.3161 - val_accuracy: 0.9107
# Epoch 100/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2420 - accuracy: 0.9091 - val_loss: 0.3142 - val_accuracy: 0.8929
# Epoch 101/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2331 - accuracy: 0.9227 - val_loss: 0.3117 - val_accuracy: 0.8929
# Epoch 102/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.2620 - accuracy: 0.8818 - val_loss: 0.3102 - val_accuracy: 0.9107
# Epoch 103/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2243 - accuracy: 0.9136 - val_loss: 0.3096 - val_accuracy: 0.9107
# Epoch 104/150
# 7/7 [==============================] - 1s 144ms/step - loss: 0.2466 - accuracy: 0.9091 - val_loss: 0.3074 - val_accuracy: 0.9107
# Epoch 105/150
# 7/7 [==============================] - 1s 132ms/step - loss: 0.2304 - accuracy: 0.9091 - val_loss: 0.3085 - val_accuracy: 0.9107
# Epoch 106/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2404 - accuracy: 0.9136 - val_loss: 0.3086 - val_accuracy: 0.9107
# Epoch 107/150
# 7/7 [==============================] - 1s 129ms/step - loss: 0.2207 - accuracy: 0.9318 - val_loss: 0.3062 - val_accuracy: 0.9286
# Epoch 108/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.2265 - accuracy: 0.9273 - val_loss: 0.3047 - val_accuracy: 0.9286
# Epoch 109/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2481 - accuracy: 0.9045 - val_loss: 0.3014 - val_accuracy: 0.9107
# Epoch 110/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2431 - accuracy: 0.9000 - val_loss: 0.3003 - val_accuracy: 0.9107
# Epoch 111/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2258 - accuracy: 0.9136 - val_loss: 0.2994 - val_accuracy: 0.9107
# Epoch 112/150
# 7/7 [==============================] - 1s 122ms/step - loss: 0.2198 - accuracy: 0.9318 - val_loss: 0.2987 - val_accuracy: 0.9286
# Epoch 113/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2180 - accuracy: 0.9273 - val_loss: 0.2990 - val_accuracy: 0.9286
# Epoch 114/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2237 - accuracy: 0.9182 - val_loss: 0.2980 - val_accuracy: 0.9286
# Epoch 115/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2186 - accuracy: 0.9182 - val_loss: 0.2961 - val_accuracy: 0.9286
# Epoch 116/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.2316 - accuracy: 0.9409 - val_loss: 0.2918 - val_accuracy: 0.9107
# Epoch 117/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2407 - accuracy: 0.9182 - val_loss: 0.2906 - val_accuracy: 0.9107
# Epoch 118/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2240 - accuracy: 0.9318 - val_loss: 0.2891 - val_accuracy: 0.9107
# Epoch 119/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2192 - accuracy: 0.9000 - val_loss: 0.2892 - val_accuracy: 0.9107
# Epoch 120/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2240 - accuracy: 0.9273 - val_loss: 0.2896 - val_accuracy: 0.9286
# Epoch 121/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2299 - accuracy: 0.9227 - val_loss: 0.2887 - val_accuracy: 0.9286
# Epoch 122/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2290 - accuracy: 0.9091 - val_loss: 0.2864 - val_accuracy: 0.9107
# Epoch 123/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2083 - accuracy: 0.9182 - val_loss: 0.2842 - val_accuracy: 0.9107
# Epoch 124/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2237 - accuracy: 0.9045 - val_loss: 0.2817 - val_accuracy: 0.9107
# Epoch 125/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2158 - accuracy: 0.9318 - val_loss: 0.2816 - val_accuracy: 0.9107
# Epoch 126/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2020 - accuracy: 0.9227 - val_loss: 0.2798 - val_accuracy: 0.9107
# Epoch 127/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2091 - accuracy: 0.9318 - val_loss: 0.2788 - val_accuracy: 0.9107
# Epoch 128/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.1922 - accuracy: 0.9409 - val_loss: 0.2777 - val_accuracy: 0.9107
# Epoch 129/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.1978 - accuracy: 0.9409 - val_loss: 0.2771 - val_accuracy: 0.9107
# Epoch 130/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2142 - accuracy: 0.9227 - val_loss: 0.2750 - val_accuracy: 0.9107
# Epoch 131/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2092 - accuracy: 0.9136 - val_loss: 0.2757 - val_accuracy: 0.9286
# Epoch 132/150
# 7/7 [==============================] - 1s 124ms/step - loss: 0.1956 - accuracy: 0.9500 - val_loss: 0.2762 - val_accuracy: 0.9286
# Epoch 133/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2154 - accuracy: 0.9091 - val_loss: 0.2762 - val_accuracy: 0.9286
# Epoch 134/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.1994 - accuracy: 0.9500 - val_loss: 0.2752 - val_accuracy: 0.9286
# Epoch 135/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2025 - accuracy: 0.9364 - val_loss: 0.2732 - val_accuracy: 0.9286
# Epoch 136/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.1934 - accuracy: 0.9227 - val_loss: 0.2732 - val_accuracy: 0.9286
# Epoch 137/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2134 - accuracy: 0.9091 - val_loss: 0.2720 - val_accuracy: 0.9286
# Epoch 138/150
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2060 - accuracy: 0.9409 - val_loss: 0.2683 - val_accuracy: 0.9286
# Epoch 139/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.1974 - accuracy: 0.9273 - val_loss: 0.2660 - val_accuracy: 0.9107
# Epoch 140/150
# 7/7 [==============================] - 1s 130ms/step - loss: 0.1944 - accuracy: 0.9364 - val_loss: 0.2657 - val_accuracy: 0.9286
# Epoch 141/150
# 7/7 [==============================] - 1s 145ms/step - loss: 0.1904 - accuracy: 0.9500 - val_loss: 0.2639 - val_accuracy: 0.9286
# Epoch 142/150
# 7/7 [==============================] - 1s 130ms/step - loss: 0.1939 - accuracy: 0.9227 - val_loss: 0.2622 - val_accuracy: 0.9286
# Epoch 143/150
# 7/7 [==============================] - 1s 128ms/step - loss: 0.1996 - accuracy: 0.9273 - val_loss: 0.2624 - val_accuracy: 0.9286
# Epoch 144/150
# 7/7 [==============================] - 1s 128ms/step - loss: 0.2042 - accuracy: 0.9318 - val_loss: 0.2631 - val_accuracy: 0.9286
# Epoch 145/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.1840 - accuracy: 0.9455 - val_loss: 0.2639 - val_accuracy: 0.9286
# Epoch 146/150
# 7/7 [==============================] - 1s 126ms/step - loss: 0.2045 - accuracy: 0.9136 - val_loss: 0.2637 - val_accuracy: 0.9286
# Epoch 147/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.1958 - accuracy: 0.9273 - val_loss: 0.2603 - val_accuracy: 0.9286
# Epoch 148/150
# 7/7 [==============================] - 1s 125ms/step - loss: 0.1938 - accuracy: 0.9409 - val_loss: 0.2582 - val_accuracy: 0.9286
# Epoch 149/150
# 7/7 [==============================] - 1s 123ms/step - loss: 0.1904 - accuracy: 0.9136 - val_loss: 0.2562 - val_accuracy: 0.9286
# Epoch 150/150
# 7/7 [==============================] - 1s 120ms/step - loss: 0.1836 - accuracy: 0.9364 - val_loss: 0.2572 - val_accuracy: 0.9286

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
base_model.save('base_model_MobileNet')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: base_model_MobileNet\assets
# C:\Users\Davran\anaconda3\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\Davran\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
