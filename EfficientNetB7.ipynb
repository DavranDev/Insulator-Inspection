# %%
import tensorflow as tf
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.7)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True, gpu_options=gpu_options))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import keras
import tensorflow as tf
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
from tensorflow.keras.applications import ResNet50
#from keras_squeezenet.squeezenet import SqueezeNet
#from keras.layers import BatchNormalization
from keras.models import Model
from keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import os
import PIL
import PIL.Image
import pathlib
from sklearn.model_selection import train_test_split
data_dir = pathlib.Path("/Users/Yernar-PC/DEEP LEARNING/PART2")
data_dir_train = pathlib.Path("/Users/Yernar-PC/DEEP LEARNING/Insulator/total data/all/*/*")
#data_dir_test = pathlib.Path("C:/Users/Davran/0_Deep_Learning_Project/Implant Inspection/test/*/*")

# %%
filenames = tf.io.gfile.glob(str(data_dir_train))
#filenames.extend(tf.io.gfile.glob(str(data_dir_test)))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %%
COUNT_CLEAN = len([filename for filename in filenames if "Clean" in filename])
print("Clean images count in training set: " + str(COUNT_CLEAN))

COUNT_POLLUTED = len([filename for filename in filenames if "Polluted" in filename])
print("Polluted images count in training set: " + str(COUNT_POLLUTED))
# Out:
# Clean images count in training set: 71
# Polluted images count in training set: 205

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\DSCF0025.JPG'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\DSCF0064.JPG'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\20200617_125813.jpg'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\20180320_123204.jpg'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\20200617_124537.jpg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Train images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validation images count: " + str(VAL_IMG_COUNT))
# Out:
# Train images count: 220
# Validation images count: 56

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(data_dir) + "/All/*")])
CLASS_NAMES
# Out:
# array([], dtype=float64)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    if parts[-2] == 'Clean':
        return 0
    else:
        return 1

# %%
def decode_img(img):
    # convert the compressed string
    img_X = tf.image.decode_jpeg(img, channels=3)
    # Use `convert_image_dtype` to convert to floats in the [0,1] range.
    img_X = tf.keras.layers.Rescaling(scale=1./127.5, offset=-1)(img_X)
    #img_X = tf.image.convert_image_dtype(img_X, tf.float32)
    # resize the image to the desired size.
    return tf.image.resize(img_X, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
IMAGE_SIZE = (100, 100)
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
X_train = []
y_train = []

for image, label in train_ds:
    X_train.append(image)
    y_train.append(label)    
X_train = np.array(X_train, dtype = 'float32')
y_train = np.array(y_train, dtype = 'float32')

shuffled_idx = np.random.permutation(TRAIN_IMG_COUNT)
X_train[:] = X_train[shuffled_idx]
y_train[:] = y_train[shuffled_idx]
print(X_train.shape)
print(y_train.shape)
# Out:
# (220, 100, 100, 3)
# (220,)

# %%
X_val = []
y_val = []

for image, label in val_ds:
    X_val.append(image)
    y_val.append(label)    
X_val = np.array(X_val, dtype = 'float32')
y_val = np.array(y_val, dtype = 'float32')

shuffled_idx = np.random.permutation(VAL_IMG_COUNT)
X_val[:] = X_val[shuffled_idx]
y_val[:] = y_val[shuffled_idx]
print(X_val.shape)
print(y_val.shape)
# Out:
# (56, 100, 100, 3)
# (56,)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (10, 10))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap = plt.cm.binary)
    plt.xlabel(y_train[i])
    
# The figure below shows the downsampled images of insulators with the labels below.
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#X_train = np.expand_dims(X_train, axis=0)

# %%
#X_train.shape

# %%
IMG_SHAPE = IMAGE_SIZE + (3, )
base_model = tf.keras.applications.EfficientNetB7(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
#image_batch, label_batch = next(iter(X_train))
feature_batch = base_model(X_train)
print(feature_batch.shape)
# Out:
# (220, 4, 4, 2560)

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 100, 100, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 100, 100, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 101, 101, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 50, 50, 64)   1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 50, 50, 64)   256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 50, 50, 64)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 50, 50, 64)   576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 50, 50, 64)   256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 50, 50, 64)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 50, 50, 64)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 50, 50, 32)   2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 50, 50, 32)   128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 50, 50, 32)   288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 50, 50, 32)   128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 50, 50, 32)   0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 50, 50, 32)   0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 50, 50, 32)   1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 50, 50, 32)   128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 50, 50, 32)   0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 50, 50, 32)   0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 50, 50, 32)   288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 50, 50, 32)   128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 50, 50, 32)   0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 50, 50, 32)   0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 50, 50, 32)   1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 50, 50, 32)   128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 50, 50, 32)   0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 50, 50, 32)   0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 50, 50, 32)   288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 50, 50, 32)   128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 50, 50, 32)   0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 50, 50, 32)   0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 50, 50, 32)   1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 50, 50, 32)   128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 50, 50, 32)   0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 50, 50, 32)   0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 50, 50, 192)  6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 50, 50, 192)  768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 50, 50, 192)  0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 51, 51, 192)  0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 25, 25, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 25, 25, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 25, 25, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 25, 25, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 25, 25, 48)   9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 25, 25, 48)   192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 25, 25, 288)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 25, 25, 288)  2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 25, 25, 288)  1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 25, 25, 288)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 25, 25, 288)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 25, 25, 48)   13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 25, 25, 48)   192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 25, 25, 48)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 25, 25, 48)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 25, 25, 288)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 25, 25, 288)  2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 25, 25, 288)  1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 25, 25, 288)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 25, 25, 288)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 25, 25, 48)   13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 25, 25, 48)   192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 25, 25, 48)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 25, 25, 48)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 25, 25, 288)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 25, 25, 288)  2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 25, 25, 288)  1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 25, 25, 288)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 25, 25, 288)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 25, 25, 48)   13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 25, 25, 48)   192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 25, 25, 48)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 25, 25, 48)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 25, 25, 288)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 25, 25, 288)  2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 25, 25, 288)  1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 25, 25, 288)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 25, 25, 288)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 25, 25, 48)   13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 25, 25, 48)   192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 25, 25, 48)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 25, 25, 48)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 25, 25, 288)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 25, 25, 288)  2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 25, 25, 288)  1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 25, 25, 288)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 25, 25, 288)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 25, 25, 48)   13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 25, 25, 48)   192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 25, 25, 48)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 25, 25, 48)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 25, 25, 288)  0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 25, 25, 288)  2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 25, 25, 288)  1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 25, 25, 288)  0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 25, 25, 288)  0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 25, 25, 48)   13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 25, 25, 48)   192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 25, 25, 48)   0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 25, 25, 48)   0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 25, 25, 288)  13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 25, 25, 288)  1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 25, 25, 288)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 29, 29, 288)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 13, 13, 288)  7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 13, 13, 288)  1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 13, 13, 288)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 13, 13, 288)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 13, 13, 80)   23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 13, 13, 80)   320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 13, 13, 480)  38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 13, 13, 480)  1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 13, 13, 480)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 13, 13, 480)  12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 13, 13, 480)  1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 13, 13, 480)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 13, 13, 480)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 13, 13, 80)   38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 13, 13, 80)   320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 13, 13, 80)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 13, 13, 80)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 13, 13, 480)  38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 13, 13, 480)  1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 13, 13, 480)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 13, 13, 480)  12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 13, 13, 480)  1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 13, 13, 480)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 13, 13, 480)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 13, 13, 80)   38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 13, 13, 80)   320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 13, 13, 80)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 13, 13, 80)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 13, 13, 480)  38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 13, 13, 480)  1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 13, 13, 480)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 13, 13, 480)  12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 13, 13, 480)  1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 13, 13, 480)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 13, 13, 480)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 13, 13, 80)   38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 13, 13, 80)   320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 13, 13, 80)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 13, 13, 80)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 13, 13, 480)  38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 13, 13, 480)  1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 13, 13, 480)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 13, 13, 480)  12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 13, 13, 480)  1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 13, 13, 480)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 13, 13, 480)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# block6m_expand_bn (BatchNormali (None, 4, 4, 2304)   9216        block6m_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6m_expand_activation (Acti (None, 4, 4, 2304)   0           block6m_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6m_dwconv (DepthwiseConv2D (None, 4, 4, 2304)   57600       block6m_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6m_bn (BatchNormalization) (None, 4, 4, 2304)   9216        block6m_dwconv[0][0]
# __________________________________________________________________________________________________
# block6m_activation (Activation) (None, 4, 4, 2304)   0           block6m_bn[0][0]
# __________________________________________________________________________________________________
# block6m_se_squeeze (GlobalAvera (None, 2304)         0           block6m_activation[0][0]
# __________________________________________________________________________________________________
# block6m_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block6m_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6m_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block6m_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6m_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block6m_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6m_se_excite (Multiply)    (None, 4, 4, 2304)   0           block6m_activation[0][0]
#                                                                  block6m_se_expand[0][0]
# __________________________________________________________________________________________________
# block6m_project_conv (Conv2D)   (None, 4, 4, 384)    884736      block6m_se_excite[0][0]
# __________________________________________________________________________________________________
# block6m_project_bn (BatchNormal (None, 4, 4, 384)    1536        block6m_project_conv[0][0]
# __________________________________________________________________________________________________
# block6m_drop (Dropout)          (None, 4, 4, 384)    0           block6m_project_bn[0][0]
# __________________________________________________________________________________________________
# block6m_add (Add)               (None, 4, 4, 384)    0           block6m_drop[0][0]
#                                                                  block6l_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 4, 4, 2304)   884736      block6m_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 4, 4, 2304)   9216        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 4, 4, 2304)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 4, 4, 2304)   20736       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 4, 4, 2304)   9216        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 4, 4, 2304)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2304)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 4, 4, 2304)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 4, 4, 640)    1474560     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 4, 4, 640)    2560        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 4, 4, 3840)   2457600     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 4, 4, 3840)   15360       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 4, 4, 3840)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 4, 4, 3840)   34560       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 4, 4, 3840)   15360       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 4, 4, 3840)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3840)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 4, 4, 3840)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 4, 4, 640)    2457600     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 4, 4, 640)    2560        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 4, 4, 640)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 4, 4, 640)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 4, 4, 3840)   2457600     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 4, 4, 3840)   15360       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 4, 4, 3840)   0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 4, 4, 3840)   34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 4, 4, 3840)   15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 4, 4, 3840)   0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 4, 4, 3840)   0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 4, 4, 640)    2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 4, 4, 640)    2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 4, 4, 640)    0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 4, 4, 640)    0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 4, 4, 3840)   2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 4, 4, 3840)   15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 4, 4, 3840)   0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 4, 4, 3840)   34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 4, 4, 3840)   15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 4, 4, 3840)   0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 4, 4, 3840)   0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 4, 4, 640)    2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 4, 4, 640)    2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (Dropout)          (None, 4, 4, 640)    0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 4, 4, 640)    0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 4, 4, 2560)   1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 4, 4, 2560)   10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 4, 4, 2560)   0           top_bn[0][0]
# ==================================================================================================
# Total params: 64,097,687
# Trainable params: 0
# Non-trainable params: 64,097,687
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (220, 2560)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (220, 1)

# %%
inputs = tf.keras.Input(shape=(100, 100, 3))
#x = data_augmentation(inputs)
#x = preprocess_input(inputs)
x = base_model(inputs, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# efficientnetb7 (Functional)  (None, 4, 4, 2560)        64097687
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2560)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2560)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2561
# =================================================================
# Total params: 64,100,248
# Trainable params: 2,561
# Non-trainable params: 64,097,687
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
type(X_val)
# Out:
# numpy.ndarray

# %%
tf.config.run_functions_eagerly(True)

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=150,
                    validation_data = (X_val, y_val)
                    )
# Out:
# Epoch 1/150
# C:\Users\Yernar-PC\anaconda3\envs\tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 7/7 [==============================] - 11s 1s/step - loss: 0.7876 - accuracy: 0.3000 - val_loss: 0.6553 - val_accuracy: 0.2500
# Epoch 2/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6387 - accuracy: 0.4455 - val_loss: 0.5671 - val_accuracy: 0.7500
# Epoch 3/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5907 - accuracy: 0.6818 - val_loss: 0.5655 - val_accuracy: 0.7500
# Epoch 4/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5877 - accuracy: 0.7364 - val_loss: 0.5714 - val_accuracy: 0.7500
# Epoch 5/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5799 - accuracy: 0.7409 - val_loss: 0.5673 - val_accuracy: 0.7500
# Epoch 6/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.5886 - accuracy: 0.7364 - val_loss: 0.5631 - val_accuracy: 0.7500
# Epoch 7/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5834 - accuracy: 0.6955 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 8/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5790 - accuracy: 0.6909 - val_loss: 0.5624 - val_accuracy: 0.7500
# Epoch 9/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6145 - accuracy: 0.6818 - val_loss: 0.5627 - val_accuracy: 0.7500
# Epoch 10/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5870 - accuracy: 0.6591 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 11/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6062 - accuracy: 0.7091 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 12/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5663 - accuracy: 0.6955 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 13/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5842 - accuracy: 0.6818 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 14/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5818 - accuracy: 0.7000 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 15/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5965 - accuracy: 0.6636 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 16/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6046 - accuracy: 0.6773 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 17/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5906 - accuracy: 0.6818 - val_loss: 0.5622 - val_accuracy: 0.7500
# Epoch 18/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6099 - accuracy: 0.6955 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 19/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6090 - accuracy: 0.6955 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 20/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5961 - accuracy: 0.7000 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 21/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5974 - accuracy: 0.6727 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 22/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5983 - accuracy: 0.6636 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 23/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6036 - accuracy: 0.7045 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 24/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6010 - accuracy: 0.6682 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 25/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5741 - accuracy: 0.7091 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 26/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.6013 - accuracy: 0.6727 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 27/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6055 - accuracy: 0.7091 - val_loss: 0.5622 - val_accuracy: 0.7500
# Epoch 28/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5735 - accuracy: 0.6864 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 29/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5742 - accuracy: 0.6727 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 30/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5798 - accuracy: 0.7182 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 31/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5943 - accuracy: 0.6727 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 32/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5995 - accuracy: 0.6682 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 33/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.6004 - accuracy: 0.6818 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 34/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5801 - accuracy: 0.6773 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 35/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5991 - accuracy: 0.6864 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 36/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5783 - accuracy: 0.6955 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 37/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5863 - accuracy: 0.6864 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 38/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5755 - accuracy: 0.7364 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 39/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5804 - accuracy: 0.7091 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 40/150
# 7/7 [==============================] - 11s 1s/step - loss: 0.5860 - accuracy: 0.6955 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 41/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6113 - accuracy: 0.6591 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 42/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5590 - accuracy: 0.7045 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 43/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6119 - accuracy: 0.6682 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 44/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5899 - accuracy: 0.6864 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 45/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5870 - accuracy: 0.6636 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 46/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5741 - accuracy: 0.7136 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 47/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5902 - accuracy: 0.7273 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 48/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6042 - accuracy: 0.7000 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 49/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5976 - accuracy: 0.6909 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 50/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5958 - accuracy: 0.6909 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 51/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5967 - accuracy: 0.7091 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 52/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6088 - accuracy: 0.7227 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 53/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5890 - accuracy: 0.7318 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 54/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6224 - accuracy: 0.6409 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 55/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5965 - accuracy: 0.6955 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 56/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5884 - accuracy: 0.7136 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 57/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.5824 - accuracy: 0.6955 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 58/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5958 - accuracy: 0.7136 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 59/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5640 - accuracy: 0.7136 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 60/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5862 - accuracy: 0.6909 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 61/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5815 - accuracy: 0.7045 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 62/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6171 - accuracy: 0.7045 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 63/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5838 - accuracy: 0.6955 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 64/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5896 - accuracy: 0.6864 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 65/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6123 - accuracy: 0.6455 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 66/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5897 - accuracy: 0.6909 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 67/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5837 - accuracy: 0.7000 - val_loss: 0.5622 - val_accuracy: 0.7500
# Epoch 68/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.5951 - accuracy: 0.7182 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 69/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5800 - accuracy: 0.7136 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 70/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5845 - accuracy: 0.6909 - val_loss: 0.5609 - val_accuracy: 0.7500
# Epoch 71/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5857 - accuracy: 0.7045 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 72/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5815 - accuracy: 0.7227 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 73/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5875 - accuracy: 0.6955 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 74/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5879 - accuracy: 0.6682 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 75/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5783 - accuracy: 0.7182 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 76/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5777 - accuracy: 0.7045 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 77/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6003 - accuracy: 0.7045 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 78/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5936 - accuracy: 0.7045 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 79/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6048 - accuracy: 0.7227 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 80/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6044 - accuracy: 0.7045 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 81/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5991 - accuracy: 0.6864 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 82/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.6040 - accuracy: 0.6818 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 83/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5895 - accuracy: 0.7000 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 84/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5927 - accuracy: 0.7091 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 85/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5968 - accuracy: 0.6864 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 86/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5943 - accuracy: 0.7045 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 87/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5968 - accuracy: 0.6591 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 88/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5804 - accuracy: 0.7136 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 89/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5842 - accuracy: 0.7182 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 90/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5758 - accuracy: 0.7000 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 91/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5827 - accuracy: 0.6909 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 92/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6072 - accuracy: 0.7136 - val_loss: 0.5605 - val_accuracy: 0.7500
# Epoch 93/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5892 - accuracy: 0.7091 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 94/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5953 - accuracy: 0.7136 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 95/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5956 - accuracy: 0.6864 - val_loss: 0.5609 - val_accuracy: 0.7500
# Epoch 96/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5846 - accuracy: 0.7000 - val_loss: 0.5605 - val_accuracy: 0.7500
# Epoch 97/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5819 - accuracy: 0.7227 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 98/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5920 - accuracy: 0.7227 - val_loss: 0.5604 - val_accuracy: 0.7500
# Epoch 99/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5779 - accuracy: 0.7591 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 100/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6121 - accuracy: 0.6909 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 101/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5920 - accuracy: 0.7000 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 102/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5876 - accuracy: 0.6591 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 103/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.5899 - accuracy: 0.6864 - val_loss: 0.5604 - val_accuracy: 0.7500
# Epoch 104/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5812 - accuracy: 0.7318 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 105/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.5618 - accuracy: 0.7318 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 106/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.5898 - accuracy: 0.6864 - val_loss: 0.5605 - val_accuracy: 0.7500
# Epoch 107/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.6037 - accuracy: 0.6500 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 108/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6069 - accuracy: 0.6682 - val_loss: 0.5603 - val_accuracy: 0.7500
# Epoch 109/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.5741 - accuracy: 0.7182 - val_loss: 0.5603 - val_accuracy: 0.7500
# Epoch 110/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.5715 - accuracy: 0.6909 - val_loss: 0.5603 - val_accuracy: 0.7500
# Epoch 111/150
# 7/7 [==============================] - 9s 1s/step - loss: 0.5945 - accuracy: 0.7182 - val_loss: 0.5605 - val_accuracy: 0.7500
# Epoch 112/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5696 - accuracy: 0.7000 - val_loss: 0.5602 - val_accuracy: 0.7500
# Epoch 113/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5962 - accuracy: 0.7136 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 114/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5891 - accuracy: 0.7227 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 115/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6056 - accuracy: 0.6909 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 116/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.6004 - accuracy: 0.7000 - val_loss: 0.5601 - val_accuracy: 0.7500
# Epoch 117/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5696 - accuracy: 0.6955 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 118/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5734 - accuracy: 0.7273 - val_loss: 0.5603 - val_accuracy: 0.7500
# Epoch 119/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5642 - accuracy: 0.7227 - val_loss: 0.5601 - val_accuracy: 0.7500
# Epoch 120/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5808 - accuracy: 0.7136 - val_loss: 0.5602 - val_accuracy: 0.7500
# Epoch 121/150
# 7/7 [==============================] - 10s 2s/step - loss: 0.5830 - accuracy: 0.7091 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 122/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6001 - accuracy: 0.7273 - val_loss: 0.5601 - val_accuracy: 0.7500
# Epoch 123/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5867 - accuracy: 0.7000 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 124/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6057 - accuracy: 0.6682 - val_loss: 0.5601 - val_accuracy: 0.7500
# Epoch 125/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5885 - accuracy: 0.6864 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 126/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5669 - accuracy: 0.7182 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 127/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5926 - accuracy: 0.6909 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 128/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5891 - accuracy: 0.7000 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 129/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6042 - accuracy: 0.6636 - val_loss: 0.5599 - val_accuracy: 0.7500
# Epoch 130/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6186 - accuracy: 0.6909 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 131/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5878 - accuracy: 0.7364 - val_loss: 0.5599 - val_accuracy: 0.7500
# Epoch 132/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5861 - accuracy: 0.7091 - val_loss: 0.5602 - val_accuracy: 0.7500
# Epoch 133/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5779 - accuracy: 0.6636 - val_loss: 0.5600 - val_accuracy: 0.7500
# Epoch 134/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5763 - accuracy: 0.7273 - val_loss: 0.5603 - val_accuracy: 0.7500
# Epoch 135/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5752 - accuracy: 0.7455 - val_loss: 0.5598 - val_accuracy: 0.7500
# Epoch 136/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6065 - accuracy: 0.6818 - val_loss: 0.5602 - val_accuracy: 0.7500
# Epoch 137/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5916 - accuracy: 0.7091 - val_loss: 0.5609 - val_accuracy: 0.7500
# Epoch 138/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5734 - accuracy: 0.7136 - val_loss: 0.5604 - val_accuracy: 0.7500
# Epoch 139/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5906 - accuracy: 0.6818 - val_loss: 0.5598 - val_accuracy: 0.7500
# Epoch 140/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5865 - accuracy: 0.6864 - val_loss: 0.5599 - val_accuracy: 0.7500
# Epoch 141/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5906 - accuracy: 0.7182 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 142/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5804 - accuracy: 0.7318 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 143/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6145 - accuracy: 0.6773 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 144/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5879 - accuracy: 0.7045 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 145/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5913 - accuracy: 0.7000 - val_loss: 0.5598 - val_accuracy: 0.7500
# Epoch 146/150
# 7/7 [==============================] - 10s 1s/step - loss: 0.5620 - accuracy: 0.7364 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 147/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5901 - accuracy: 0.7000 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 148/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.6056 - accuracy: 0.6909 - val_loss: 0.5596 - val_accuracy: 0.7500
# Epoch 149/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5869 - accuracy: 0.7000 - val_loss: 0.5598 - val_accuracy: 0.7500
# Epoch 150/150
# 7/7 [==============================] - 11s 2s/step - loss: 0.5986 - accuracy: 0.6636 - val_loss: 0.5604 - val_accuracy: 0.7500

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
