# %%
import keras
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
#from keras.layers import BatchNormalization
from keras.models import Model
from keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import os
import PIL
import PIL.Image
import pathlib
from sklearn.model_selection import train_test_split
data_dir = pathlib.Path("/Users/Yernar-PC/DEEP LEARNING/PART2")
data_dir_train = pathlib.Path("/Users/Yernar-PC/DEEP LEARNING/Insulator/total data/all/*/*")
#data_dir_test = pathlib.Path("C:/Users/Davran/0_Deep_Learning_Project/Implant Inspection/test/*/*")

# %%
filenames = tf.io.gfile.glob(str(data_dir_train))
#filenames.extend(tf.io.gfile.glob(str(data_dir_test)))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %%
COUNT_CLEAN = len([filename for filename in filenames if "Clean" in filename])
print("Clean images count in training set: " + str(COUNT_CLEAN))

COUNT_POLLUTED = len([filename for filename in filenames if "Polluted" in filename])
print("Polluted images count in training set: " + str(COUNT_POLLUTED))
# Out:
# Clean images count in training set: 71
# Polluted images count in training set: 205

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\20200617_125742.jpg'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Clean\\20200617_125556.jpg'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Polluted\\20200617_124528.jpg'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Clean\\20200617_125451.jpg'
# b'\\Users\\Yernar-PC\\DEEP LEARNING\\Insulator\\total data\\all\\Clean\\20200617_125718.jpg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Train images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validation images count: " + str(VAL_IMG_COUNT))
# Out:
# Train images count: 220
# Validation images count: 56

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(data_dir) + "/All/*")])
CLASS_NAMES
# Out:
# array([], dtype=float64)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    if parts[-2] == 'Clean':
        return 0
    else:
        return 1

# %%
def decode_img(img):
    # convert the compressed string
    img_X = tf.image.decode_jpeg(img, channels=3)
    # Use `convert_image_dtype` to convert to floats in the [0,1] range.
    img_X = tf.keras.layers.Rescaling(scale=1./127.5, offset=-1)(img_X)
    #img_X = tf.image.convert_image_dtype(img_X, tf.float32)
    # resize the image to the desired size.
    return tf.image.resize(img_X, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
IMAGE_SIZE = (224, 224)
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
X_train = []
y_train = []

for image, label in train_ds:
    X_train.append(image)
    y_train.append(label)    
X_train = np.array(X_train, dtype = 'float32')
y_train = np.array(y_train, dtype = 'float32')

shuffled_idx = np.random.permutation(TRAIN_IMG_COUNT)
X_train[:] = X_train[shuffled_idx]
y_train[:] = y_train[shuffled_idx]
print(X_train.shape)
print(y_train.shape)
# Out:
# (220, 224, 224, 3)
# (220,)

# %%
X_val = []
y_val = []

for image, label in val_ds:
    X_val.append(image)
    y_val.append(label)    
X_val = np.array(X_val, dtype = 'float32')
y_val = np.array(y_val, dtype = 'float32')

shuffled_idx = np.random.permutation(VAL_IMG_COUNT)
X_val[:] = X_val[shuffled_idx]
y_val[:] = y_val[shuffled_idx]
print(X_val.shape)
print(y_val.shape)
# Out:
# (56, 224, 224, 3)
# (56,)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (10, 10))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap = plt.cm.binary)
    plt.xlabel(y_train[i])
    
# The figure below shows the downsampled images of insulators with the labels below.
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#X_train = np.expand_dims(X_train, axis=0)

# %%
#X_train.shape

# %%
IMG_SHAPE = IMAGE_SIZE + (3, )
base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
#image_batch, label_batch = next(iter(X_train))
feature_batch = base_model(X_train)
print(feature_batch.shape)
# Out:
# (220, 7, 7, 2048)

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (220, 2048)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (220, 1)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
#x = data_augmentation(inputs)
#x = preprocess_input(inputs)
x = base_model(inputs, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,589,761
# Trainable params: 2,049
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
type(X_val)
# Out:
# numpy.ndarray

# %%
tf.config.run_functions_eagerly(True)

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=150,
                    validation_data = (X_val, y_val)
                    )
# Out:
# C:\Users\Yernar-PC\anaconda3\envs\tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# Epoch 1/150
# 7/7 [==============================] - 5s 510ms/step - loss: 1.6700 - accuracy: 0.2727 - val_loss: 1.7276 - val_accuracy: 0.1964
# Epoch 2/150
# 7/7 [==============================] - 2s 220ms/step - loss: 1.5638 - accuracy: 0.2727 - val_loss: 1.6176 - val_accuracy: 0.1964
# Epoch 3/150
# 7/7 [==============================] - 2s 219ms/step - loss: 1.4760 - accuracy: 0.2727 - val_loss: 1.5104 - val_accuracy: 0.1964
# Epoch 4/150
# 7/7 [==============================] - 2s 220ms/step - loss: 1.3573 - accuracy: 0.2727 - val_loss: 1.4107 - val_accuracy: 0.1964
# Epoch 5/150
# 7/7 [==============================] - 2s 220ms/step - loss: 1.2581 - accuracy: 0.2727 - val_loss: 1.3153 - val_accuracy: 0.1964
# Epoch 6/150
# 7/7 [==============================] - 2s 220ms/step - loss: 1.1857 - accuracy: 0.2727 - val_loss: 1.2264 - val_accuracy: 0.1964
# Epoch 7/150
# 7/7 [==============================] - 2s 220ms/step - loss: 1.1142 - accuracy: 0.2727 - val_loss: 1.1432 - val_accuracy: 0.1964
# Epoch 8/150
# 7/7 [==============================] - 2s 219ms/step - loss: 1.0815 - accuracy: 0.2727 - val_loss: 1.0644 - val_accuracy: 0.1964
# Epoch 9/150
# 7/7 [==============================] - 2s 221ms/step - loss: 1.0208 - accuracy: 0.2727 - val_loss: 0.9933 - val_accuracy: 0.1964
# Epoch 10/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.9300 - accuracy: 0.2773 - val_loss: 0.9297 - val_accuracy: 0.1964
# Epoch 11/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.9044 - accuracy: 0.2818 - val_loss: 0.8720 - val_accuracy: 0.1964
# Epoch 12/150
# 7/7 [==============================] - 2s 219ms/step - loss: 0.8803 - accuracy: 0.2818 - val_loss: 0.8216 - val_accuracy: 0.1964
# Epoch 13/150
# 7/7 [==============================] - 2s 219ms/step - loss: 0.8256 - accuracy: 0.3000 - val_loss: 0.7768 - val_accuracy: 0.1964
# Epoch 14/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.7585 - accuracy: 0.3500 - val_loss: 0.7384 - val_accuracy: 0.1964
# Epoch 15/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.7325 - accuracy: 0.3136 - val_loss: 0.7052 - val_accuracy: 0.1964
# Epoch 16/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.7331 - accuracy: 0.3273 - val_loss: 0.6768 - val_accuracy: 0.1964
# Epoch 17/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6932 - accuracy: 0.3955 - val_loss: 0.6522 - val_accuracy: 0.1964
# Epoch 18/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6883 - accuracy: 0.3773 - val_loss: 0.6313 - val_accuracy: 0.2143
# Epoch 19/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6795 - accuracy: 0.4091 - val_loss: 0.6139 - val_accuracy: 0.2321
# Epoch 20/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6584 - accuracy: 0.4318 - val_loss: 0.5976 - val_accuracy: 0.2679
# Epoch 21/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6513 - accuracy: 0.4409 - val_loss: 0.5843 - val_accuracy: 0.3929
# Epoch 22/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6507 - accuracy: 0.4182 - val_loss: 0.5725 - val_accuracy: 0.5536
# Epoch 23/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6313 - accuracy: 0.4909 - val_loss: 0.5627 - val_accuracy: 0.6607
# Epoch 24/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6192 - accuracy: 0.5273 - val_loss: 0.5537 - val_accuracy: 0.6786
# Epoch 25/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.6257 - accuracy: 0.5364 - val_loss: 0.5462 - val_accuracy: 0.7143
# Epoch 26/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5887 - accuracy: 0.6091 - val_loss: 0.5396 - val_accuracy: 0.7321
# Epoch 27/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5865 - accuracy: 0.6455 - val_loss: 0.5348 - val_accuracy: 0.7321
# Epoch 28/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6093 - accuracy: 0.6000 - val_loss: 0.5298 - val_accuracy: 0.7679
# Epoch 29/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6182 - accuracy: 0.6091 - val_loss: 0.5257 - val_accuracy: 0.7857
# Epoch 30/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5924 - accuracy: 0.6455 - val_loss: 0.5222 - val_accuracy: 0.8036
# Epoch 31/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6054 - accuracy: 0.6091 - val_loss: 0.5191 - val_accuracy: 0.8036
# Epoch 32/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5947 - accuracy: 0.6636 - val_loss: 0.5160 - val_accuracy: 0.8036
# Epoch 33/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6063 - accuracy: 0.6318 - val_loss: 0.5139 - val_accuracy: 0.8036
# Epoch 34/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5783 - accuracy: 0.6591 - val_loss: 0.5119 - val_accuracy: 0.8036
# Epoch 35/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6468 - accuracy: 0.6045 - val_loss: 0.5100 - val_accuracy: 0.8036
# Epoch 36/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5929 - accuracy: 0.6182 - val_loss: 0.5086 - val_accuracy: 0.8036
# Epoch 37/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6081 - accuracy: 0.6318 - val_loss: 0.5073 - val_accuracy: 0.8036
# Epoch 38/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6302 - accuracy: 0.6182 - val_loss: 0.5057 - val_accuracy: 0.8036
# Epoch 39/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5958 - accuracy: 0.6636 - val_loss: 0.5043 - val_accuracy: 0.8036
# Epoch 40/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6066 - accuracy: 0.6318 - val_loss: 0.5033 - val_accuracy: 0.8036
# Epoch 41/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5748 - accuracy: 0.7136 - val_loss: 0.5024 - val_accuracy: 0.8036
# Epoch 42/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5949 - accuracy: 0.6864 - val_loss: 0.5016 - val_accuracy: 0.8036
# Epoch 43/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6178 - accuracy: 0.6364 - val_loss: 0.5006 - val_accuracy: 0.8036
# Epoch 44/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6041 - accuracy: 0.7000 - val_loss: 0.4994 - val_accuracy: 0.8036
# Epoch 45/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5912 - accuracy: 0.6500 - val_loss: 0.4982 - val_accuracy: 0.8036
# Epoch 46/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6103 - accuracy: 0.6636 - val_loss: 0.4975 - val_accuracy: 0.8036
# Epoch 47/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5901 - accuracy: 0.6864 - val_loss: 0.4968 - val_accuracy: 0.8036
# Epoch 48/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6115 - accuracy: 0.7000 - val_loss: 0.4960 - val_accuracy: 0.8036
# Epoch 49/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5905 - accuracy: 0.6727 - val_loss: 0.4959 - val_accuracy: 0.8036
# Epoch 50/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5898 - accuracy: 0.6818 - val_loss: 0.4956 - val_accuracy: 0.8036
# Epoch 51/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6179 - accuracy: 0.6500 - val_loss: 0.4953 - val_accuracy: 0.8036
# Epoch 52/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5979 - accuracy: 0.6636 - val_loss: 0.4950 - val_accuracy: 0.8036
# Epoch 53/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5795 - accuracy: 0.6682 - val_loss: 0.4948 - val_accuracy: 0.8036
# Epoch 54/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5961 - accuracy: 0.6682 - val_loss: 0.4946 - val_accuracy: 0.8036
# Epoch 55/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5940 - accuracy: 0.6909 - val_loss: 0.4937 - val_accuracy: 0.8036
# Epoch 56/150
# 7/7 [==============================] - 2s 220ms/step - loss: 0.6018 - accuracy: 0.6682 - val_loss: 0.4933 - val_accuracy: 0.8036
# Epoch 57/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5996 - accuracy: 0.7000 - val_loss: 0.4927 - val_accuracy: 0.8036
# Epoch 58/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5933 - accuracy: 0.7045 - val_loss: 0.4925 - val_accuracy: 0.8036
# Epoch 59/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5903 - accuracy: 0.6500 - val_loss: 0.4922 - val_accuracy: 0.8036
# Epoch 60/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5956 - accuracy: 0.7091 - val_loss: 0.4919 - val_accuracy: 0.8036
# Epoch 61/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5680 - accuracy: 0.6818 - val_loss: 0.4915 - val_accuracy: 0.8036
# Epoch 62/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5694 - accuracy: 0.6864 - val_loss: 0.4908 - val_accuracy: 0.8036
# Epoch 63/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.6007 - accuracy: 0.6818 - val_loss: 0.4896 - val_accuracy: 0.8036
# Epoch 64/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5907 - accuracy: 0.6818 - val_loss: 0.4889 - val_accuracy: 0.8036
# Epoch 65/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5920 - accuracy: 0.6682 - val_loss: 0.4880 - val_accuracy: 0.8036
# Epoch 66/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5856 - accuracy: 0.7227 - val_loss: 0.4872 - val_accuracy: 0.8036
# Epoch 67/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5824 - accuracy: 0.7227 - val_loss: 0.4868 - val_accuracy: 0.8036
# Epoch 68/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5840 - accuracy: 0.7091 - val_loss: 0.4866 - val_accuracy: 0.8036
# Epoch 69/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5936 - accuracy: 0.6727 - val_loss: 0.4863 - val_accuracy: 0.8036
# Epoch 70/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5743 - accuracy: 0.6955 - val_loss: 0.4864 - val_accuracy: 0.8036
# Epoch 71/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5682 - accuracy: 0.7273 - val_loss: 0.4862 - val_accuracy: 0.8036
# Epoch 72/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5828 - accuracy: 0.7000 - val_loss: 0.4853 - val_accuracy: 0.8036
# Epoch 73/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5737 - accuracy: 0.7364 - val_loss: 0.4853 - val_accuracy: 0.8036
# Epoch 74/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5698 - accuracy: 0.6955 - val_loss: 0.4851 - val_accuracy: 0.8036
# Epoch 75/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5874 - accuracy: 0.7227 - val_loss: 0.4846 - val_accuracy: 0.8036
# Epoch 76/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5946 - accuracy: 0.6773 - val_loss: 0.4843 - val_accuracy: 0.8036
# Epoch 77/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5930 - accuracy: 0.6909 - val_loss: 0.4840 - val_accuracy: 0.8036
# Epoch 78/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5845 - accuracy: 0.7182 - val_loss: 0.4838 - val_accuracy: 0.8036
# Epoch 79/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.5738 - accuracy: 0.7045 - val_loss: 0.4835 - val_accuracy: 0.8036
# Epoch 80/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5688 - accuracy: 0.7000 - val_loss: 0.4840 - val_accuracy: 0.8036
# Epoch 81/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5644 - accuracy: 0.7182 - val_loss: 0.4832 - val_accuracy: 0.8036
# Epoch 82/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5633 - accuracy: 0.7273 - val_loss: 0.4834 - val_accuracy: 0.8036
# Epoch 83/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5611 - accuracy: 0.6864 - val_loss: 0.4839 - val_accuracy: 0.8036
# Epoch 84/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5688 - accuracy: 0.7000 - val_loss: 0.4836 - val_accuracy: 0.8036
# Epoch 85/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5702 - accuracy: 0.7045 - val_loss: 0.4825 - val_accuracy: 0.8036
# Epoch 86/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5789 - accuracy: 0.6955 - val_loss: 0.4818 - val_accuracy: 0.8036
# Epoch 87/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5770 - accuracy: 0.6818 - val_loss: 0.4818 - val_accuracy: 0.8036
# Epoch 88/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5573 - accuracy: 0.6955 - val_loss: 0.4820 - val_accuracy: 0.8036
# Epoch 89/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5670 - accuracy: 0.6955 - val_loss: 0.4813 - val_accuracy: 0.8036
# Epoch 90/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5568 - accuracy: 0.7318 - val_loss: 0.4807 - val_accuracy: 0.8036
# Epoch 91/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5885 - accuracy: 0.6955 - val_loss: 0.4800 - val_accuracy: 0.8036
# Epoch 92/150
# 7/7 [==============================] - 2s 228ms/step - loss: 0.5658 - accuracy: 0.7136 - val_loss: 0.4796 - val_accuracy: 0.8036
# Epoch 93/150
# 7/7 [==============================] - 2s 226ms/step - loss: 0.5535 - accuracy: 0.7182 - val_loss: 0.4793 - val_accuracy: 0.8036
# Epoch 94/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5643 - accuracy: 0.7000 - val_loss: 0.4785 - val_accuracy: 0.8036
# Epoch 95/150
# 7/7 [==============================] - 2s 231ms/step - loss: 0.5756 - accuracy: 0.7182 - val_loss: 0.4779 - val_accuracy: 0.8036
# Epoch 96/150
# 7/7 [==============================] - 2s 232ms/step - loss: 0.5707 - accuracy: 0.6955 - val_loss: 0.4775 - val_accuracy: 0.8036
# Epoch 97/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.5749 - accuracy: 0.6727 - val_loss: 0.4776 - val_accuracy: 0.8036
# Epoch 98/150
# 7/7 [==============================] - 2s 240ms/step - loss: 0.5722 - accuracy: 0.6818 - val_loss: 0.4774 - val_accuracy: 0.8036
# Epoch 99/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5537 - accuracy: 0.7364 - val_loss: 0.4772 - val_accuracy: 0.8036
# Epoch 100/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5938 - accuracy: 0.6818 - val_loss: 0.4761 - val_accuracy: 0.8036
# Epoch 101/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5846 - accuracy: 0.6591 - val_loss: 0.4752 - val_accuracy: 0.8036
# Epoch 102/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5715 - accuracy: 0.6909 - val_loss: 0.4744 - val_accuracy: 0.8036
# Epoch 103/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5866 - accuracy: 0.6864 - val_loss: 0.4740 - val_accuracy: 0.8036
# Epoch 104/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5703 - accuracy: 0.7091 - val_loss: 0.4734 - val_accuracy: 0.8036
# Epoch 105/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5787 - accuracy: 0.7136 - val_loss: 0.4728 - val_accuracy: 0.8036
# Epoch 106/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5941 - accuracy: 0.6773 - val_loss: 0.4723 - val_accuracy: 0.8036
# Epoch 107/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5852 - accuracy: 0.6682 - val_loss: 0.4719 - val_accuracy: 0.8036
# Epoch 108/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5421 - accuracy: 0.7500 - val_loss: 0.4716 - val_accuracy: 0.8036
# Epoch 109/150
# 7/7 [==============================] - 2s 228ms/step - loss: 0.5823 - accuracy: 0.6818 - val_loss: 0.4708 - val_accuracy: 0.8036
# Epoch 110/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5560 - accuracy: 0.7409 - val_loss: 0.4707 - val_accuracy: 0.8036
# Epoch 111/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5843 - accuracy: 0.7273 - val_loss: 0.4710 - val_accuracy: 0.8036
# Epoch 112/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5752 - accuracy: 0.6773 - val_loss: 0.4713 - val_accuracy: 0.8036
# Epoch 113/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5798 - accuracy: 0.6727 - val_loss: 0.4706 - val_accuracy: 0.8036
# Epoch 114/150
# 7/7 [==============================] - 2s 228ms/step - loss: 0.5567 - accuracy: 0.7318 - val_loss: 0.4703 - val_accuracy: 0.8036
# Epoch 115/150
# 7/7 [==============================] - 2s 226ms/step - loss: 0.5646 - accuracy: 0.6909 - val_loss: 0.4700 - val_accuracy: 0.8036
# Epoch 116/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5779 - accuracy: 0.6909 - val_loss: 0.4696 - val_accuracy: 0.8036
# Epoch 117/150
# 7/7 [==============================] - 2s 226ms/step - loss: 0.5563 - accuracy: 0.7182 - val_loss: 0.4696 - val_accuracy: 0.8036
# Epoch 118/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5713 - accuracy: 0.7045 - val_loss: 0.4696 - val_accuracy: 0.8036
# Epoch 119/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5802 - accuracy: 0.7136 - val_loss: 0.4694 - val_accuracy: 0.8036
# Epoch 120/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5628 - accuracy: 0.7136 - val_loss: 0.4689 - val_accuracy: 0.8036
# Epoch 121/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5629 - accuracy: 0.7136 - val_loss: 0.4681 - val_accuracy: 0.8036
# Epoch 122/150
# 7/7 [==============================] - 2s 227ms/step - loss: 0.5688 - accuracy: 0.7182 - val_loss: 0.4676 - val_accuracy: 0.8036
# Epoch 123/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.5881 - accuracy: 0.7045 - val_loss: 0.4679 - val_accuracy: 0.8036
# Epoch 124/150
# 7/7 [==============================] - 2s 225ms/step - loss: 0.5693 - accuracy: 0.6773 - val_loss: 0.4676 - val_accuracy: 0.8036
# Epoch 125/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5733 - accuracy: 0.7227 - val_loss: 0.4667 - val_accuracy: 0.8036
# Epoch 126/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5739 - accuracy: 0.6864 - val_loss: 0.4666 - val_accuracy: 0.8036
# Epoch 127/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5516 - accuracy: 0.7318 - val_loss: 0.4661 - val_accuracy: 0.8036
# Epoch 128/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5523 - accuracy: 0.7227 - val_loss: 0.4664 - val_accuracy: 0.8036
# Epoch 129/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5606 - accuracy: 0.7091 - val_loss: 0.4657 - val_accuracy: 0.8036
# Epoch 130/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5617 - accuracy: 0.7455 - val_loss: 0.4652 - val_accuracy: 0.8036
# Epoch 131/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5615 - accuracy: 0.7273 - val_loss: 0.4641 - val_accuracy: 0.8036
# Epoch 132/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5537 - accuracy: 0.7091 - val_loss: 0.4642 - val_accuracy: 0.8036
# Epoch 133/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5680 - accuracy: 0.7136 - val_loss: 0.4642 - val_accuracy: 0.8036
# Epoch 134/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5494 - accuracy: 0.7364 - val_loss: 0.4637 - val_accuracy: 0.8036
# Epoch 135/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5792 - accuracy: 0.7091 - val_loss: 0.4636 - val_accuracy: 0.8036
# Epoch 136/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5908 - accuracy: 0.6864 - val_loss: 0.4631 - val_accuracy: 0.8036
# Epoch 137/150
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5415 - accuracy: 0.7182 - val_loss: 0.4619 - val_accuracy: 0.8036
# Epoch 138/150
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5515 - accuracy: 0.7318 - val_loss: 0.4624 - val_accuracy: 0.8036
# Epoch 139/150
# 7/7 [==============================] - 2s 226ms/step - loss: 0.5456 - accuracy: 0.7318 - val_loss: 0.4623 - val_accuracy: 0.8036
# Epoch 140/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5699 - accuracy: 0.6818 - val_loss: 0.4624 - val_accuracy: 0.8036
# Epoch 141/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5562 - accuracy: 0.6955 - val_loss: 0.4621 - val_accuracy: 0.8036
# Epoch 142/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5669 - accuracy: 0.7091 - val_loss: 0.4614 - val_accuracy: 0.8036
# Epoch 143/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5664 - accuracy: 0.7091 - val_loss: 0.4604 - val_accuracy: 0.8036
# Epoch 144/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5745 - accuracy: 0.6955 - val_loss: 0.4596 - val_accuracy: 0.8036
# Epoch 145/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5657 - accuracy: 0.7000 - val_loss: 0.4588 - val_accuracy: 0.8036
# Epoch 146/150
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5745 - accuracy: 0.6909 - val_loss: 0.4581 - val_accuracy: 0.8036
# Epoch 147/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5776 - accuracy: 0.7227 - val_loss: 0.4578 - val_accuracy: 0.8036
# Epoch 148/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5642 - accuracy: 0.7000 - val_loss: 0.4574 - val_accuracy: 0.8036
# Epoch 149/150
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5280 - accuracy: 0.7591 - val_loss: 0.4568 - val_accuracy: 0.8036
# Epoch 150/150
# 7/7 [==============================] - 2s 219ms/step - loss: 0.5672 - accuracy: 0.7000 - val_loss: 0.4580 - val_accuracy: 0.8036

# %%
history.result
